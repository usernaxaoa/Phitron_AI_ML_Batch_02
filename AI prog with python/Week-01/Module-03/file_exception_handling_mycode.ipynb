# %%
print("File Handling")
# Out:
# File Handling

# %%
# file read and wite

# open('file_location', mod)
# mod:
# 1. read - r
# 2. write - w (existing data clear hoye jay)
# 3. append - a (data ja chilo tar porer theke add kora suru korbe)

# %%
# can open a file in 2 ways

# file = open("./sample_data/sample.txt", "r")
# content = file.read()
# print(content)
# print(type(content))

# %%
# file = open("./sample_data/sample.txt", "r")
# content = file.readlines()
# print(content)
# print(file.closed)
# file.close()
# print(file.closed)

# %%
# with open("./sample_data/sample.txt", "r") as file:
#   content = file.readlines()
#   print(content)
# print(file.closed)

# %%
# with open("./sample_data/sample.txt", "r") as file:
#   for line in file:
#     # print(line, end="")
#     l = line.strip()
#     print(l)

# %%
# write in a file by creating

# with open("./sample_data/test.txt", "w") as file:
#   file.write("Hello test file\n")
#   file.write("Ai ml batch 02\n")
#   file.write("learning file read write")

# print(file.closed)

# %%
# writing on a existing file

# with open("./sample_data/test.txt", "w") as file:
#   file.write("second attemp\n")
#   file.write("Ai ml batch 02\n")

# %%
# write or appending in existing file without over writting
# with open("./sample_data/test.txt", "a") as file:
  # file.write("second attemp\n")
  # file.write("Ai ml batch 02")
  # file.write("cse sucks, totally sucks")

# %%
# with open("./sample_data/test.txt") as file:
#   content = file.readlines()
#   content = list(map(str.strip, content))

#   filter_content = list(filter(lambda x : len(x) > 13, content))
# print(filter_content)

# %%
# string = ['nafiz ', 'mahmud ', 'shawon\n']
# with open("./sample_data/test2.txt", "w") as file:
#   file.writelines(string)

# %%
# file pointer

# with open("./sample_data/point.txt", "r") as file:
#   print(file.tell())
#   file.seek(5)
#   print(file.read())
  # file.seek(0)
  # print(file.read())


  # print(file.read())
  # print(file.read(4))
  # print(file.tell())

# %%
# a = 10/0

n = int(input())
try:
  a = 10/n
  print("hello world")
except ZeroDivisionError:
  print("you can't divide by zero")
print("Hello world")
# Out:
# 0
# you can't divide by zero
# Hello world

# %%
try:
  x = y
except Exception as exe:
  print(exe)

# %%
# model train
try:
  file = open("./sample_data/test3.txt", "r")
except Exception as e:
  print(e)
else:
  # train the model
  print(file.read())
finally:
  file.close()
  print("file closed")
# Out:
# [Errno 2] No such file or directory: './sample_data/test3.txt'
# file closed

# %%
file = open("./sample_data/test3.txt", "r")
content = file.read()
print(content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3302/4237087086.py in <cell line: 0>()
# ----> 1 file = open("./sample_data/test3.txt", "r")
#       2 content = file.read()
#       3 print(content)
#
# FileNotFoundError: [Errno 2] No such file or directory: './sample_data/test3.txt'
