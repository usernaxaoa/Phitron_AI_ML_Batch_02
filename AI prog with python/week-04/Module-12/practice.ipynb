# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    'A': [1, 2, np.nan, 4, 5],
    'B': [5, np.nan, np.nan, None, 10],
    'C': ['a', 'b', 'c', None, 'e']
})

df
# Out:
#      A     B     C
# 0  1.0   5.0     a
# 1  2.0   NaN     b
# 2  NaN   NaN     c
# 3  4.0   NaN  None
# 4  5.0  10.0     e

# %%
df['A'].fillna(df['A'].mean())
df['B'].ffill(df['B'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df['A'].fillna(df['A'].mean())
#       2 df['B'].ffill(df['B'])
#
# File ~\Desktop\Phitron_AI_ML_Batch_02\phitronenv\lib\site-packages\pandas\core\series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File ~\Desktop\Phitron_AI_ML_Batch_02\phitronenv\lib\site-packages\pandas\core\series.py:1249, in Series._get_value(self, label, takeable)
#    1246     return self._values[label]
#    1248 # Similar to Index.get_value, but we do not fall back to positional
# -> 1249 loc = self.index.get_loc(label)
# ...
