# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
hours = [1, 2, 3, 4, 5]
marks = [10, 23, 20, 47, 40]

plt.plot(hours, marks)
plt.xlabel('hours')
plt.ylabel('marks')
plt.title('hours vs marks')
plt.show()
