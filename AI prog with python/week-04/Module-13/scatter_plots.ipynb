# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# to find correlation between features

students = pd.read_csv('student_data.csv')

plt.xlabel("age")
plt.ylabel("socioeconomic")
plt.title("relation iq by age and socioeconomic")
plt.scatter(students['Age'], students['socioeconomic'])

plt.grid()
plt.show()
# students.head(10)
