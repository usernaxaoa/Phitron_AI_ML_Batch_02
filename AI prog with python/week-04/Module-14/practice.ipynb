# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('sales.csv')
df
# Out:
#            date  sales
# 0    2025-01-01  12500
# 1    2025-01-02  13800
# 2    2025-01-03  14200
# 3    2025-01-04  15100
# 4    2025-01-05  14900
# ..          ...    ...
# 115  2025-04-26  36500
# 116  2025-04-27  38200
# 117  2025-04-28  39900
# 118  2025-04-29  41500
# 119  2025-04-30  40100
#
# [120 rows x 2 columns]

# %%
plt.plot(df['date'], df['sales'])

# %%
df.columns
# Out:
# Index(['date', 'sales'], dtype='object')

# %%
df = pd.read_csv('students.csv')
df.columns
# Out:
# Index(['student_id', 'student_name', 'gender', 'age', 'hours_studied', 'marks',
#        'subject', 'attendance_percentage', 'previous_gpa'],
#       dtype='object')

# %%
sns.relplot(data=df, x='hours_studied', y='marks', hue='gender')

# %%
sns.scatterplot(data=df, x='hours_studied', y='marks', hue='subject')
plt.grid()
plt.show()

# %%
sns.histplot(data=df, x='marks',kde=True)
# Out:
# <Axes: xlabel='marks', ylabel='Count'>

# %%
sns.kdeplot(df, x='hours_studied')
# Out:
# <Axes: xlabel='hours_studied', ylabel='Density'>

# %%
sns.countplot(df, x='subject')
# Out:
# <Axes: xlabel='subject', ylabel='count'>

# %%
sns.regplot(df, x='hours_studied', y='marks')
# Out:
# <Axes: xlabel='hours_studied', ylabel='marks'>

# %%
sns.pairplot(df, hue='gender')
