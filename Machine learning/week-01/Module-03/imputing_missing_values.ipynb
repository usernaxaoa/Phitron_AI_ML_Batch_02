# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.model_selection import SimpleImputer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 6
#       4 import seaborn as sns
#       5 from sklearn.model_selection import train_test_split
# ----> 6 from sklearn.model_selection import SimpleImputer
#
# ImportError: cannot import name 'SimpleImputer' from 'sklearn.model_selection' (c:\Users\nafiz\Desktop\Phitron_AI_ML_Batch_02\phitronenv\lib\site-packages\sklearn\model_selection\__init__.py)

# %%
df = pd.read_csv('titanic_data_updated.csv')
df.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1, inplace=True)

# %%
x = df.drop(['Survived'], axis=1)
x
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0     third    male  22.0      1      0   7.2500        S
# 1     first  female  38.0      1      0  71.2833        C
# 2     third  female  26.0      0      0   7.9250        S
# 3     first  female  35.0      1      0  53.1000        S
# 4     third    male  35.0      0      0   8.0500        S
# ..      ...     ...   ...    ...    ...      ...      ...
# 886  second    male  27.0      0      0  13.0000        S
# 887   first  female  19.0      0      0  30.0000        S
# 888   third  female   NaN      1      2  23.4500        S
# 889   first    male  26.0      0      0  30.0000        C
# 890   third    male  32.0      0      0   7.7500        Q
#
# [891 rows x 7 columns]

# %%
y = df['Survived']
y
# Out:
# 0       no
# 1      yes
# 2      yes
# 3      yes
# 4       no
#       ...
# 886     no
# 887    yes
# 888     no
# 889    yes
# 890     no
# Name: Survived, Length: 891, dtype: object

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# note
""" 
deleting missing values row (not good always)
deleting the columns
"""

# impute
""" 
# numerical
either mean (normal distribution)
or median (skewed distribution)
Code:
pandas -> fillna()
ml way [SimpleImputerr] - Ecosystem [pipeline] - Columntransformer

# categorical
mode(frequency berr kore jeta besi)
missing
"""
# Out:
# ' \n# numerical\neither mean (normal distribution)\nor median (skewed distribution)\nCode:\npandas -> fillna()\nml way [SimpleImputerr] - Ecosystem [pipeline] - Columntransformer\n\n# categorical\nmode(frequency berr kore jeta besi)\nmissing\n'

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
x_train.isnull().sum()
# Out:
# Pclass        0
# Sex           0
# Age         140
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
age_mean = x_train['Age'].mean()
x_train['age_mean'] = x_train['Age'].fillna(age_mean)

age_median = x_train['Age'].median()
x_train['age_median'] = x_train['Age'].fillna(age_median)

# %%
age_median = x_test['Age'].mean()
x_test['age_median'] = x_test['Age'].fillna(age_median)

age_mean = x_test['Age'].mean()
x_test['age_mean'] = x_test['Age'].fillna(age_mean)

# %%
display(x_train.isnull().sum())
display(x_test.isnull().sum())
# Out:
# Pclass          0
# Sex             0
# Age           140
# SibSp           0
# Parch           0
# Fare            0
# Embarked        2
# age_mean        0
# age_median      0
# dtype: int64
# Pclass         0
# Sex            0
# Age           37
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# age_median     0
# age_mean       0
# dtype: int64

# %%
sns.kdeplot(data=x_train, x='age_mean')
plt.show()

# %%
sns.kdeplot(data=x_train, x='age_median')
# Out:
# <Axes: xlabel='age_median', ylabel='Density'>
