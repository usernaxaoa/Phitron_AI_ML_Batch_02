# %%
""" 

EDA 

# type of data
# amount of data
# data distribution
# spotting missing data
# outliers
# relationship between features

method for EDA -
# analytical analysis
# univariate analysis
# bi-variate and multi variate
# y-data profiling

"""
# Out:
# ' \n\nEDA \n\n# type of data\n# amount of data\n# data distribution\n# spotting missing data\n# outliers\n# relationship between features\n\nmethod for EDA -\n# analytical analysis\n# univariate analysis\n# bi-variate and multi variate\n# y-data profiling\n\n'

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('titanic_data_updated.csv')
df.head(10)
# Out:
#    PassengerId Survived  Pclass  \
# 0            1       no   third
# 1            2      yes   first
# 2            3      yes   third
# 3            4      yes   first
# 4            5       no   third
# 5            6       no   third
# 6            7       no   first
# 7            8       no   third
# 8            9      yes   third
# 9           10      yes  second
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %%
data_shape = df.shape
print(f"Potential features {data_shape[1]}")
print(f"Potential sample {data_shape[0]}")
# Out:
# Potential features 12
# Potential sample 891

# %%
df.head(10)
# Out:
#    PassengerId Survived  Pclass  \
# 0            1       no   third
# 1            2      yes   first
# 2            3      yes   third
# 3            4      yes   first
# 4            5       no   third
# 5            6       no   third
# 6            7       no   first
# 7            8       no   third
# 8            9      yes   third
# 9           10      yes  second
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %%
df.sample(10)
# Out:
#      PassengerId Survived  Pclass  \
# 285          286       no   third
# 826          827       no   third
# 886          887       no  second
# 501          502       no   third
# 30            31       no   first
# 240          241       no   third
# 613          614       no   third
# 146          147      yes   third
# 220          221      yes   third
# 180          181       no   third
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 285                           Stankovic, Mr. Ivan    male  33.0      0      0
# 826                                  Lam, Mr. Len    male   NaN      0      0
# 886                         Montvila, Rev. Juozas    male  27.0      0      0
# 501                           Canavan, Miss. Mary  female  21.0      0      0
# 30                       Uruchurtu, Don. Manuel E    male  40.0      0      0
# 240                         Zabour, Miss. Thamine  female   NaN      1      0
# ...

# %%
# missing 

print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# checking duplicates

print(df.duplicated().sum())
df.drop_duplicates(inplace=True)
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    object
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 83.7+ KB

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.describe()
# Out:
#        PassengerId         Age       SibSp       Parch        Fare
# count   891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.699118    0.523008    0.381594   32.204208
# std     257.353842   14.526497    1.102743    0.806057   49.693429
# min       1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000   38.000000    1.000000    0.000000   31.000000
# max     891.000000   80.000000    8.000000    6.000000  512.329200

# %%
# uni variate analysis 

df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sns.countplot(data=df, x=df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
survival = (df['Survived'].value_counts() / len(df)) * 100
survival
# Out:
# Survived
# no     61.616162
# yes    38.383838
# Name: count, dtype: float64

# %%
# label = survival.index
label = df['Survived'].unique()
print(label)

plt.pie(df['Survived'].value_counts() / len(df), autopct='%1.1f%%', labels=label)
plt.show()
# Out:
# ['no' 'yes']

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0              1       no   third
# 1              2      yes   first
# 2              3      yes   third
# 3              4      yes   first
# 4              5       no   third
# ..           ...      ...     ...
# 886          887       no  second
# 887          888      yes   first
# 888          889       no   third
# 889          890      yes   first
# 890          891       no   third
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Pclass'].unique()
# Out:
# array(['third', 'first', 'second'], dtype=object)

# %%
sns.countplot(df, x=df['Pclass'], hue=df['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
label = df['Pclass'].unique()
print(label)

plt.pie(df['Pclass'].value_counts() / len(df), autopct='%1.1f%%', labels=label)
plt.show()
# Out:
# ['third' 'first' 'second']

# %%
label = df['Sex'].unique()
print(label)

plt.pie(df['Sex'].value_counts() / len(df), autopct='%1.1f%%', labels=label)
plt.show()
# Out:
# ['male' 'female']

# %%
sns.countplot(df, x=df['Sex'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sns.countplot(df, x=df['Embarked'])
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
label = df['Embarked'].unique()
plt.pie((df['Embarked'].value_counts()/len(df)) * 100, autopct='%1.1f%%', labels=label)
plt.show()
