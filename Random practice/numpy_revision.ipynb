# %%
import numpy as np

# %%
arr = [1,2,3]
print(arr * 5)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
arr = np.array([1,2,3])
print(arr * 5)
# Out:
# [ 5 10 15]

# %%
arr1 = np.array([1,2,3])
print(arr1.ndim)
print(arr1.dtype)
print(arr1.shape)
# Out:
# 1
# int64
# (3,)

# %%
arr2 = np.array([[1,2,3],[1,2,3]])
print(arr2.ndim)
print(arr2.dtype)
print(arr2.shape)
# Out:
# 2
# int64
# (2, 3)

# %%
arr3 = np.array([[[1,2], [3,4]], [[1,2],[3,4]]])
print(arr3.ndim)
print(arr3.dtype)
print(arr3.shape)
# Out:
# 3
# int64
# (2, 2, 2)

# %%
dtypee = np.array([1,2,3.4, '5'], dtype=np.float16)
print(dtypee)
print(dtypee.dtype)
# Out:
# [1.  2.  3.4 5. ]
# float16

# %%
dtypee = np.array([1,2,3.4, '5'], dtype=np.float16)
dtypee.astype(np.float16)
print(dtypee)
print(dtypee.dtype)
# Out:
# [1.  2.  3.4 5. ]
# float16

# %%
arr = np.array([1,'2', 3.3, True])
print(arr.dtype)
print(arr)
# Out:
# <U32
# ['1' '2' '3.3' 'True']

# %%
lst = [10,20,30,40.7]
arr = np.array(lst)
arr = arr.astype(np.int32)
print(arr)
print(arr.dtype)
print(type(arr))
# Out:
# [10 20 30 40]
# int32
# <class 'numpy.ndarray'>

# %%
tpl = (1,2,3,4,5)
tpl = np.array(tpl)
print(type(tpl))
print(tpl.dtype)
print(tpl.ndim)
print(tpl.shape)
# Out:
# <class 'numpy.ndarray'>
# int64
# 1
# (5,)

# %%
st = {1,2,3,4}
st = np.array((st))
print(type(st))
print(st.dtype)
print(st.ndim)
print(st.shape)
# Out:
# <class 'numpy.ndarray'>
# object
# 0
# ()

# %%
dc = {'a': 10, 'b': 20, 'c': 30}

key = dc.keys()
value = dc.values()
item = dc.items()

k = np.array(key)
print(type(k))
print(k)

v = np.array(value)
print(type(v))
print(v)

i = np.array(list(item))
print(type(i))
print(i)
# Out:
# <class 'numpy.ndarray'>
# dict_keys(['a', 'b', 'c'])
# <class 'numpy.ndarray'>
# dict_values([10, 20, 30])
# <class 'numpy.ndarray'>
# [['a' '10']
#  ['b' '20']
#  ['c' '30']]

# %%
arr = np.random.rand(3,3) 
print(arr)
print(arr.dtype)
# Out:
# [[0.69498399 0.14472361 0.87420402]
#  [0.03827921 0.31549319 0.09373534]
#  [0.51314397 0.75393091 0.56851503]]
# float64

# %%
arr = np.random.randint(1, 10, (10,10))
print(arr)
print(arr.dtype)
# Out:
# [[7 2 4 6 8 9 4 2 9 4]
#  [7 9 2 5 9 2 8 6 5 4]
#  [7 5 9 5 3 5 7 1 9 8]
#  [7 2 5 1 5 9 1 4 5 8]
#  [5 7 4 4 1 6 1 6 3 8]
#  [3 1 2 8 6 1 7 2 3 3]
#  [9 2 5 6 1 3 6 3 8 8]
#  [8 7 1 4 4 7 2 7 4 3]
#  [7 9 8 9 9 5 6 4 9 6]
#  [3 2 4 2 9 3 7 7 2 1]]
# int32

# %%
arr = np.random.uniform(1, 10, (3,3))
print(arr)
print(arr.dtype)
# Out:
# [[7.80118477 2.51797243 4.13147061]
#  [9.62384185 8.17809093 2.67486921]
#  [7.74478244 9.57934788 4.70584476]]
# float64

# %%
arr = np.arange(1,10, 3).reshape(3,)
print(arr)
# Out:
# [1 4 7]

# %%
arr = np.linspace(1, 10, 19)
print(arr)
# Out:
# [ 1.   1.5  2.   2.5  3.   3.5  4.   4.5  5.   5.5  6.   6.5  7.   7.5
#   8.   8.5  9.   9.5 10. ]

# %%
arr = np.logspace(0, 4, 5, base=8)
print(arr)
# Out:
# [1.000e+00 8.000e+00 6.400e+01 5.120e+02 4.096e+03]

# %%
arr = np.array([1,2,3,4,5])
print(arr[::])
# Out:
# [1 2 3 4 5]

# %%
arr2 = np.array([[1,2,3],
                [4,5,6]])
print(arr2[0][1])

print(arr2[0:,0:2])

print(arr2[::-1,::-1])
# Out:
# 2
# [[1 2]
#  [4 5]]
# [[6 5 4]
#  [3 2 1]]

# %%
arr2 = np.array([[1,2,3],
                [4,5,6]])
print(arr2[::-1,::-1])
# Out:
# [[6 5 4]
#  [3 2 1]]

# %%
arr2[:,:1]
# Out:
# array([[1],
#        [4]])

# %%
arr = np.array([[1,2],
               [3,4]])

arr[0:1, 1:] == 300
print(arr)
# Out:
# [[1 2]
#  [3 4]]

# %%
arr = np.array([1,2,3,4])
arr2 = arr[1:3].copy()
# arr2 = arr[1:3]


print(arr)
print(arr2)

arr2[1:2] = 100

print(arr)
print(arr2)
# Out:
# [1 2 3 4]
# [2 3]
# [1 2 3 4]
# [  2 100]

# %%
lst = np.array([1,2,3,4,4])
values = lst[[2,3,3]]
print(lst)
print(values)
# Out:
# [1 2 3 4 4]
# [3 4 4]

# %%
twod = np.array([[1,8,9],
                 [6,3,4]])
print(twod[1:,1:2])
# Out:
# [[3]]

# %%
print(lst[lst > 2])
# Out:
# [3 4 4]

# %%
arr = np.array([[1,2,3],[4,5,6]])
for i in arr:
    for j in i:
        print(j)
    print(i)
# Out:
# 1
# 2
# 3
# [1 2 3]
# 4
# 5
# 6
# [4 5 6]

# %%
arr = np.array([[1,2,3],[4,5,6]])
for i in np.nditer(arr):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
data = [1,2,3,4,5]
temp_in_cel = np.array(data)
print(temp_in_cel * 1.8 + 32)
# Out:
# [33.8 35.6 37.4 39.2 41. ]

# %%
data = [1,2,3,4,5]
lap_times = np.array(data)
lap_times_in_minute = np.round((lap_times / 60).copy(),2)
print(lap_times)
print(lap_times_in_minute)
# Out:
# [1 2 3 4 5]
# [0.02 0.03 0.05 0.07 0.08]

# %%
arr = np.random.randint(1,99, size=(10,5))
print(arr)
# Out:
# [[33  8 62 43 90]
#  [ 3 21 35 45 42]
#  [ 4 58 55 37 40]
#  [94 18 93  2 14]
#  [34 67 64 61 85]
#  [81 94 19 21 60]
#  [13 47 59 50 18]
#  [16 38 96 65 21]
#  [42 42 19  8 82]
#  [79 45 83 28 54]]

# %%
print(arr.shape)
print(arr)
arr = arr.reshape(5,10) 
print(arr.shape)
print(arr)
# Out:
# (10, 5)
# [[33  8 62 43 90]
#  [ 3 21 35 45 42]
#  [ 4 58 55 37 40]
#  [94 18 93  2 14]
#  [34 67 64 61 85]
#  [81 94 19 21 60]
#  [13 47 59 50 18]
#  [16 38 96 65 21]
#  [42 42 19  8 82]
#  [79 45 83 28 54]]
# (5, 10)
# [[33  8 62 43 90  3 21 35 45 42]
#  [ 4 58 55 37 40 94 18 93  2 14]
#  [34 67 64 61 85 81 94 19 21 60]
#  [13 47 59 50 18 16 38 96 65 21]
#  [42 42 19  8 82 79 45 83 28 54]]

# %%
arr.ndim
# Out:
# 2

# %%
flatt = arr.flatten()

# %%
flatt.ndim
# Out:
# 1

# %%
print(arr)
# Out:
# [[33  8 62 43 90  3 21 35 45 42]
#  [ 4 58 55 37 40 94 18 93  2 14]
#  [34 67 64 61 85 81 94 19 21 60]
#  [13 47 59 50 18 16 38 96 65 21]
#  [42 42 19  8 82 79 45 83 28 54]]

# %%
print(flatt)
# Out:
# [33  8 62 43 90  3 21 35 45 42  4 58 55 37 40 94 18 93  2 14 34 67 64 61
#  85 81 94 19 21 60 13 47 59 50 18 16 38 96 65 21 42 42 19  8 82 79 45 83
#  28 54]

# %%
rav = np.ravel(arr, order='K')

# %%
print(rav)
# Out:
# [33  8 62 43 90  3 21 35 45 42  4 58 55 37 40 94 18 93  2 14 34 67 64 61
#  85 81 94 19 21 60 13 47 59 50 18 16 38 96 65 21 42 42 19  8 82 79 45 83
#  28 54]

# %%
a = np.random.randint(1, 10, (2,3))
b = np.random.randint(11, 20, (2,3))
print(a)
print(b)
# Out:
# [[9 5 7]
#  [3 2 1]]
# [[18 15 12]
#  [18 15 18]]

# %%
con = np.concatenate((a, b), axis=1)
print(con)
# Out:
# [[ 9  5  7 18 15 12]
#  [ 3  2  1 18 15 18]]

# %%
con = np.concatenate((a, b), axis=0)
print(con)
# Out:
# [[ 9  5  7]
#  [ 3  2  1]
#  [18 15 12]
#  [18 15 18]]

# %%
mat = np.array([
    [1,2,3],
    [4,5,6]
])

transpost = mat.T
transpost
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
a = np.random.randint(1, 10, (9,))
print(a)
# Out:
# [1 6 7 4 6 1 7 4 8]

# %%
split_arr = np.array_split(a, 3) 
print(split_arr)
# Out:
# [array([1, 6, 7], dtype=int32), array([4, 6, 1], dtype=int32), array([7, 4, 8], dtype=int32)]

# %%
split_arr = np.split(a, 3)
print(split_arr)
# Out:
# [array([1, 6, 7], dtype=int32), array([4, 6, 1], dtype=int32), array([7, 4, 8], dtype=int32)]

# %%
a
# Out:
# array([1, 6, 7, 4, 6, 1, 7, 4, 8], dtype=int32)

# %%
sinn = np.sin(a)
sinn
# Out:
# array([ 0.84147098, -0.2794155 ,  0.6569866 , -0.7568025 , -0.2794155 ,
#         0.84147098,  0.6569866 , -0.7568025 ,  0.98935825])

# %%
coss = np.cos(a)
coss
# Out:
# array([ 0.54030231,  0.96017029,  0.75390225, -0.65364362,  0.96017029,
#         0.54030231,  0.75390225, -0.65364362, -0.14550003])

# %%
degtored = np.rad2deg(a)
degtored
# Out:
# array([ 57.29577951, 343.77467708, 401.07045659, 229.18311805,
#        343.77467708,  57.29577951, 401.07045659, 229.18311805,
#        458.3662361 ])

# %%
ten_base_log = np.log10(a)
ten_base_log
# Out:
# array([0.        , 0.77815125, 0.84509804, 0.60205999, 0.77815125,
#        0.        , 0.84509804, 0.60205999, 0.90308999])

# %%
two_base_log = np.log2(a)
print(two_base_log)
# Out:
# [0.         2.5849625  2.80735492 2.         2.5849625  0.
#  2.80735492 2.         3.        ]

# %%
sqrt = np.sqrt(a)
print(sqrt)
# Out:
# [1.         2.44948974 2.64575131 2.         2.44948974 1.
#  2.64575131 2.         2.82842712]

# %%
x = np.array([10,800,16,100])
y = np.array([2,3,4,5])
print(x < y)
print(x > y)
print(x == y)
# Out:
# [False False False False]
# [ True  True  True  True]
# [False False False False]

# %%
print(np.all(x>y))
# Out:
# True

# %%
x
# Out:
# array([ 10, 800,  16, 100])

# %%
z = x.copy()

# %%
z
# Out:
# array([ 10, 800,  16, 100])

# %%
z.sort()
z
# Out:
# array([ 10,  16, 100, 800])

# %%
x
# Out:
# array([ 10, 800,  16, 100])

# %%
x
# Out:
# array([ 10, 800,  16, 100])

# %%
z
# Out:
# array([ 10,  16, 100, 800])

# %%
sort_arr = np.sort(x)
sort_arr
# Out:
# array([ 10,  16, 100, 800])

# %%
x
# Out:
# array([ 10, 800,  16, 100])

# %%
z
# Out:
# array([ 10,  16, 100, 800])

# %%
mat = np.array([[1,30,9],
               [5,4,8]])
hor_sort = np.sort(mat, axis=1)
print(hor_sort)
print()
ver_sort = np.sort(mat, axis=0)
print(ver_sort)
# Out:
# [[ 1  9 30]
#  [ 4  5  8]]
#
# [[ 1  4  8]
#  [ 5 30  9]]

# %%
x
# Out:
# array([ 10, 800,  16, 100])

# %%
print(x)
# Out:
# [ 10 800  16 100]

# %%
index = np.where(x>8)
print(index)
# Out:
# (array([0, 1, 2, 3]),)

# %%
index = np.where(x>8, x, 0)
print(index)
# Out:
# [ 10 800  16 100]

# %%
mat
# Out:
# array([[ 1, 30,  9],
#        [ 5,  4,  8]])

# %%
index = np.where(mat > 5)

# %%
index
# Out:
# (array([0, 0, 1]), array([1, 2, 2]))

# %%
index = np.where(mat<8, mat, 0)
print(index)
# Out:
# [[1 0 0]
#  [5 4 0]]

# %%
x
# Out:
# array([ 10, 800,  16, 100])

# %%
index = np.argmax(x)
print(index)
print(x[index])
# Out:
# 1
# 800

# %%
index = np.argmin(x)
print(index)
print(x[index])
# Out:
# 0
# 10

# %%
rand = np.random.randint(1,100,size=100)

# %%
print(rand)
# Out:
# [87 27 66 27 52 66 21  5 60 23 38 78 56  4 51 56 27 99 34  9 86 88 99 42
#  91  9 58 58 33 75 77 15 35 54 21 84 64 88 66 85 97 83 44 49 26  5 46 42
#  57 98 27 37 64 60 50 16 83 87 34 21 62 67 46 80  1 29 19 32 81 70 98 15
#  56  6 59 84 44 10 35 61  7 84 63 33 47 63 53 91 54 41 84 85 28  3 19 35
#  21 13 69 42]

# %%
count_number = np.count_nonzero(rand==70)
print(count_number)
# Out:
# 1

# %%
uniq = np.unique(rand, return_counts = True)
print(uniq)
# Out:
# (array([ 1,  3,  4,  5,  6,  7,  9, 10, 13, 15, 16, 19, 21, 23, 26, 27, 28,
#        29, 32, 33, 34, 35, 37, 38, 41, 42, 44, 46, 47, 49, 50, 51, 52, 53,
#        54, 56, 57, 58, 59, 60, 61, 62, 63, 64, 66, 67, 69, 70, 75, 77, 78,
#        80, 81, 83, 84, 85, 86, 87, 88, 91, 97, 98, 99], dtype=int32), array([1, 1, 1, 2, 1, 1, 2, 1, 1, 2, 1, 2, 4, 1, 1, 4, 1, 1, 1, 2, 2, 3,
#        1, 1, 1, 3, 2, 2, 1, 1, 1, 1, 1, 1, 2, 3, 1, 2, 1, 2, 1, 1, 2, 2,
#        3, 1, 1, 1, 1, 1, 1, 1, 1, 2, 4, 2, 1, 2, 2, 2, 1, 2, 2]))
