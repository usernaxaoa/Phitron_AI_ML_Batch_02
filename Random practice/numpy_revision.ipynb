# %%
import numpy as np

# %%
arr = [1,2,3]
print(arr * 5)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
arr = np.array([1,2,3])
print(arr * 5)
# Out:
# [ 5 10 15]

# %%
arr1 = np.array([1,2,3])
print(arr1.ndim)
print(arr1.dtype)
print(arr1.shape)
# Out:
# 1
# int64
# (3,)

# %%
arr2 = np.array([[1,2,3],[1,2,3]])
print(arr2.ndim)
print(arr2.dtype)
print(arr2.shape)
# Out:
# 2
# int64
# (2, 3)

# %%
arr3 = np.array([[[1,2], [3,4]], [[1,2],[3,4]]])
print(arr3.ndim)
print(arr3.dtype)
print(arr3.shape)
# Out:
# 3
# int64
# (2, 2, 2)

# %%
dtypee = np.array([1,2,3.4, '5'], dtype=np.float16)
print(dtypee)
print(dtypee.dtype)
# Out:
# [1.  2.  3.4 5. ]
# float16

# %%
dtypee = np.array([1,2,3.4, '5'], dtype=np.float16)
dtypee.astype(np.float16)
print(dtypee)
print(dtypee.dtype)
# Out:
# [1.  2.  3.4 5. ]
# float16

# %%
arr = np.array([1,'2', 3.3, True])
print(arr.dtype)
print(arr)
# Out:
# <U32
# ['1' '2' '3.3' 'True']

# %%
lst = [10,20,30,40.7]
arr = np.array(lst)
arr = arr.astype(np.int32)
print(arr)
print(arr.dtype)
print(type(arr))
# Out:
# [10 20 30 40]
# int32
# <class 'numpy.ndarray'>

# %%
tpl = (1,2,3,4,5)
tpl = np.array(tpl)
print(type(tpl))
print(tpl.dtype)
print(tpl.ndim)
print(tpl.shape)
# Out:
# <class 'numpy.ndarray'>
# int64
# 1
# (5,)

# %%
st = {1,2,3,4}
st = np.array((st))
print(type(st))
print(st.dtype)
print(st.ndim)
print(st.shape)
# Out:
# <class 'numpy.ndarray'>
# object
# 0
# ()

# %%
dc = {'a': 10, 'b': 20, 'c': 30}

key = dc.keys()
value = dc.values()
item = dc.items()

k = np.array(key)
print(type(k))
print(k)

v = np.array(value)
print(type(v))
print(v)

i = np.array(list(item))
print(type(i))
print(i)
# Out:
# <class 'numpy.ndarray'>
# dict_keys(['a', 'b', 'c'])
# <class 'numpy.ndarray'>
# dict_values([10, 20, 30])
# <class 'numpy.ndarray'>
# [['a' '10']
#  ['b' '20']
#  ['c' '30']]

# %%
arr = np.random.rand(3,3) 
print(arr)
print(arr.dtype)
# Out:
# [[0.58818449 0.98319447 0.6874967 ]
#  [0.53778265 0.04240123 0.17025402]
#  [0.8543616  0.74895715 0.27802016]]
# float64

# %%
arr = np.random.randint(1, 10, (10,10))
print(arr)
print(arr.dtype)
# Out:
# [[9 9 2 2 1 8 5 9 8 9]
#  [6 2 5 9 8 4 1 1 4 1]
#  [7 3 4 7 4 2 6 5 3 2]
#  [3 8 2 3 9 8 8 5 6 5]
#  [4 9 1 5 6 6 3 3 1 9]
#  [8 1 2 6 2 5 9 2 3 6]
#  [7 5 8 8 9 7 1 2 1 3]
#  [4 4 3 2 4 1 9 7 9 9]
#  [7 9 5 7 2 1 6 1 7 7]
#  [5 2 2 5 9 4 5 3 3 6]]
# int32

# %%
arr = np.random.uniform(1, 10, (3,3))
print(arr)
print(arr.dtype)
# Out:
# [[5.39627799 5.16069608 5.76869511]
#  [7.95263607 4.11316203 9.91946267]
#  [7.36396212 4.15178741 2.37827893]]
# float64

# %%
arr = np.arange(1,10, 3).reshape(3,)
print(arr)
# Out:
# [1 4 7]

# %%
arr = np.linspace(1, 10, 19)
print(arr)
# Out:
# [ 1.   1.5  2.   2.5  3.   3.5  4.   4.5  5.   5.5  6.   6.5  7.   7.5
#   8.   8.5  9.   9.5 10. ]

# %%
arr = np.logspace(0, 4, 5, base=8)
print(arr)
# Out:
# [1.000e+00 8.000e+00 6.400e+01 5.120e+02 4.096e+03]

# %%
arr = np.array([1,2,3,4,5])
print(arr[::])
# Out:
# [1 2 3 4 5]

# %%
arr2 = np.array([[1,2,3],
                [4,5,6]])
print(arr2[0][1])

print(arr2[0:,0:2])

print(arr2[::-1,::-1])
# Out:
# 2
# [[1 2]
#  [4 5]]
# [[6 5 4]
#  [3 2 1]]

# %%
arr2 = np.array([[1,2,3],
                [4,5,6]])
print(arr2[::-1,::-1])
# Out:
# [[6 5 4]
#  [3 2 1]]

# %%
arr2[:,:1]
# Out:
# array([[1],
#        [4]])

# %%
arr = np.array([[1,2],
               [3,4]])

arr[0:1, 1:] == 300
print(arr)
# Out:
# [[1 2]
#  [3 4]]

# %%
arr = np.array([1,2,3,4])
arr2 = arr[1:3].copy()
# arr2 = arr[1:3]


print(arr)
print(arr2)

arr2[1:2] = 100

print(arr)
print(arr2)
# Out:
# [1 2 3 4]
# [2 3]
# [1 2 3 4]
# [  2 100]

# %%
lst = np.array([1,2,3,4,4])
values = lst[[2,3,3]]
print(lst)
print(values)
# Out:
# [1 2 3 4 4]
# [3 4 4]

# %%
twod = np.array([[1,8,9],
                 [6,3,4]])
print(twod[1:,1:2])
# Out:
# [[3]]

# %%
print(lst[lst > 2])
# Out:
# [3 4 4]

# %%
arr = np.array([[1,2,3],[4,5,6]])
for i in arr:
    for j in i:
        print(j)
    print(i)
# Out:
# 1
# 2
# 3
# [1 2 3]
# 4
# 5
# 6
# [4 5 6]

# %%
arr = np.array([[1,2,3],[4,5,6]])
for i in np.nditer(arr):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
data = [1,2,3,4,5]
temp_in_cel = np.array(data)
print(temp_in_cel * 1.8 + 32)
# Out:
# [33.8 35.6 37.4 39.2 41. ]

# %%
data = [1,2,3,4,5]
lap_times = np.array(data)
lap_times_in_minute = np.round((lap_times / 60).copy(),2)
print(lap_times)
print(lap_times_in_minute)
# Out:
# [1 2 3 4 5]
# [0.02 0.03 0.05 0.07 0.08]

# %%
arr = np.random.randint(1,99, size=(10,5))
print(arr)
# Out:
# [[22 10 76 52 95]
#  [52 80  9 34 95]
#  [26  1 69 48 65]
#  [66 29 68 26 94]
#  [73 79 49 97 81]
#  [50 27 10 59 57]
#  [97 74 49 58 73]
#  [56 39 80 21 61]
#  [17 32 15 43  5]
#  [49 45 85 41 14]]

# %%
print(arr.shape)
print(arr)
arr = arr.reshape(5,10) 
print(arr.shape)
print(arr)
# Out:
# (10, 5)
# [[22 10 76 52 95]
#  [52 80  9 34 95]
#  [26  1 69 48 65]
#  [66 29 68 26 94]
#  [73 79 49 97 81]
#  [50 27 10 59 57]
#  [97 74 49 58 73]
#  [56 39 80 21 61]
#  [17 32 15 43  5]
#  [49 45 85 41 14]]
# (5, 10)
# [[22 10 76 52 95 52 80  9 34 95]
#  [26  1 69 48 65 66 29 68 26 94]
#  [73 79 49 97 81 50 27 10 59 57]
#  [97 74 49 58 73 56 39 80 21 61]
#  [17 32 15 43  5 49 45 85 41 14]]
